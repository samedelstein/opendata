# %%
from google.cloud import bigquery
import os
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd
import datetime
from google.cloud import bigquery
import pytz
from google.oauth2 import service_account
import numpy as np
import requests
from datetime import datetime as dt
from datetime import date

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = r'.\creds\opendatadbt-f2e674527eb6.json'
client = bigquery.Client()

credentials = ServiceAccountCredentials.from_json_keyfile_name(r'.\creds\opendatadbt-f2e674527eb6.json') # Your json file here

# %% [markdown]
# #initial load kc_table_id = "opendatadbt.311.kc311"
#
# kc311 = requests.get("https://data.kcmo.org/resource/7at3-sxhp.json? limit=10000& where=creation_date >= '2021-03-17T00:00:00.000'" ) kc311json = kc311.json() kc_df = pd.DataFrame(kc311json) kc_df = kc_df[['creation_date', 'closed_date','department','work_group','request_type','zip_code','street_address','status','ycoordinate','xcoordinate']] kc_df

# %%
#Incremental load
nyc_table_id = "opendatadbt.311.kc311"
current_datetime = dt.today().strftime("%Y-%m-%dT%H:%M:%S.000")
query_string = """
SELECT 
max(creation_date), max(closed_date)
FROM `opendatadbt.311.kc311`
limit 10
"""

kcmaxopendatedataframe = (
    client.query(query_string)
    .result()
    .to_dataframe()
)
kcmaxopendatedate = str(kcmaxopendatedataframe['f0_'][0])

kcmaxclosedatedataframe = (
    client.query(query_string)
    .result()
    .to_dataframe()
)
kcmaxclosedate = str(kcmaxclosedatedataframe['f1_'][0])

# %%
kc311 = requests.get("https://data.kcmo.org/resource/7at3-sxhp.json?$limit=50000&$where=creation_date>'"+kcmaxopendatedate+"' OR closed_date between '" +kcmaxclosedate+ "' AND '" + current_datetime + "'") 
kc311json = kc311.json()

# %%
cols = ['case_id','creation_date', 'closed_date','department','work_group','request_type','zip_code','street_address','status','ycoordinate','xcoordinate']
kc_df = pd.DataFrame(kc311json, columns=cols)
kc_df
# Out:
#        case_id            creation_date              closed_date  \
# 0   2021021369  2021-03-01T00:00:00.000  2021-03-25T00:00:00.000
# 1   2021021433  2021-03-01T00:00:00.000  2021-03-25T00:00:00.000
# 2   2021017859  2021-02-22T00:00:00.000  2021-03-25T00:00:00.000
# 3   2020158093  2020-12-23T00:00:00.000  2021-03-25T00:00:00.000
# 4   2020154780  2020-12-11T00:00:00.000  2021-03-25T00:00:00.000
# 5   2021022088  2021-03-02T00:00:00.000  2021-03-25T00:00:00.000
# 6   2021022122  2021-03-02T00:00:00.000  2021-03-25T00:00:00.000
# 7   2021002098  2021-01-06T00:00:00.000  2021-03-25T00:00:00.000
# 8   2021022336  2021-03-03T00:00:00.000  2021-03-25T00:00:00.000
# 9   2021005436  2021-01-15T00:00:00.000  2021-03-25T00:00:00.000
# 10  2021022710  2021-03-03T00:00:00.000  2021-03-25T00:00:00.000
# 11  2021022556  2021-03-03T00:00:00.000  2021-03-25T00:00:00.000
# 12  2021022639  2021-03-03T00:00:00.000  2021-03-25T00:00:00.000
# 13  2021021757  2021-03-02T00:00:00.000  2021-03-25T00:00:00.000
# 14  2021022584  2021-03-03T00:00:00.000  2021-03-25T00:00:00.000
# 15  2021014178  2021-02-12T00:00:00.000  2021-03-25T00:00:00.000
# 16  2021022176  2021-03-02T00:00:00.000  2021-03-25T00:00:00.000
# 17  2021015071  2021-02-16T00:00:00.000  2021-03-25T00:00:00.000
# 18  2021020204  2021-02-25T00:00:00.000  2021-03-25T00:00:00.000
# 19  2020153362  2020-12-08T00:00:00.000  2021-03-25T00:00:00.000
# 20  2021020541  2021-02-26T00:00:00.000  2021-03-25T00:00:00.000
# 21  2021020582  2021-02-26T00:00:00.000  2021-03-25T00:00:00.000
# 22  2021020952  2021-02-28T00:00:00.000  2021-03-25T00:00:00.000
#
#                        department  \
# 0                    Public Works
# 1                    Public Works
# 2   City Planning and Development
# 3                    Public Works
# 4                    Public Works
# 5                    Public Works
# 6                    Public Works
# 7                    Public Works
# 8                  Water Services
# 9                    Public Works
# 10                 Water Services
# 11                 Water Services
# 12                 Water Services
# 13                   Public Works
# 14                   Public Works
# 15                   Public Works
# 16                  Parks and Rec
# 17                 Water Services
# 18                   Public Works
# 19                   Public Works
# 20                   Public Works
# 21  City Planning and Development
# 22                   Public Works
#
#                                        work_group  \
# 0      Public Works-Street and Traffic-District 1
# 1      Public Works-Street and Traffic-District 1
# 2   City Planning and Development-Dev Comp-Zoning
# 3             Public Works-Capital Projects-Signs
# 4   Public Works-Capital Projects-Traffic Permits
# 5      Public Works-Street and Traffic-District 1
# 6      Public Works-Street and Traffic-District 2
# 7      Public Works-Street and Traffic-District 1
# 8        Water Services-Meter and Field Services-
# 9      Public Works-Street and Traffic-District 2
# 10       Water Services-Meter and Field Services-
# 11       Water Services-Meter and Field Services-
# 12       Water Services-Meter and Field Services-
# 13     Public Works-Street and Traffic-District 1
# 14     Public Works-Street and Traffic-District 1
# 15     Public Works-Street and Traffic-District 3
# 16      Parks and Rec-Landscape Services-Forestry
# 17       Water Services-Line Maintenance-Pipeline
# 18     Public Works-Street and Traffic-District 3
# 19     Public Works-Street and Traffic-District 1
# 20     Public Works-Street and Traffic-District 3
# 21  City Planning and Development-Dev Comp-Zoning
# 22     Public Works-Street and Traffic-District 1
#
#                                          request_type zip_code  \
# 0      Streets / Roadways / Alleys-Pothole-District 1    64157
# 1      Streets / Roadways / Alleys-Pothole-District 1    64119
# 2   Prop/Build/Construct-Land Use / Zoning Issue-B...    64133
# 3          Signs-Traffic Sign-Damaged – Non-Emergency    64106
# 4   Streets / Roadways / Alleys-Street Services-Tr...    64145
# 5      Streets / Roadways / Alleys-Pothole-District 1    64155
# 6          Streets / Roadways / Alleys-Pothole-Bridge    64155
# 7   Streets/Roadways/Alleys-Other Maintenance-Dist...    64151
# 8                                    Water-Leak-Meter    64114
# 9   Streets/Roadways/Alleys-Other Maintenance-Dist...    64124
# 10                                   Water-Leak-Meter    64117
# 11                 Water-No Water / Pressure-No Water    64153
# 12               Water - MFS Referral - Investigation    64129
# 13     Streets / Roadways / Alleys-Pothole-District 1    64119
# 14     Streets / Roadways / Alleys-Pothole-District 1    64151
# 15     Streets / Roadways / Alleys-Pothole-District 3    64114
# 16                          Trees-Trimming-Tree Limbs    64114
# 17                    Water-Pipeline Referral-Hydrant    64109
# 18     Streets / Roadways / Alleys-Pothole-District 3    64113
# 19  Streets/Roadways/Alleys-Other Maintenance-Dist...    64117
# 20     Streets / Roadways / Alleys-Pothole-District 3    64113
# 21  Vehicles / Parking-Commercial Vehicle-On priva...    64127
# 22     Streets / Roadways / Alleys-Pothole-District 1    64151
#
#                 street_address status ycoordinate xcoordinate
# 0             8596 N Lewis Ave  RESOL   39.247881  -94.470421
# 1   6050 NE Pleasant Valley Rd  RESOL   39.218253  -94.509788
# 2              10811 E 51st St  RESOL   39.029128  -94.451932
# 3                  921 Main St  RESOL   39.102609  -94.582728
# 4        411 W Blue Ridge Blvd  RESOL   38.890251  -94.601402
# 5             8901 N Holmes St  RESOL   39.255541  -94.571395
# 6              8948 N Oak Trfy  RESOL   39.256635  -94.576279
# 7             4320 NW 79th Ter  RESOL   39.238983  -94.628481
# 8       11401 Pennsylvania Ave  RESOL   38.920902  -94.599673
# 9           634 Van Brunt Blvd  RESOL   39.104159  -94.526186
# 10             3109 NE 43rd St   CANC   39.171253  -94.542862
# 11     9200 NW Prairie View Rd   CANC    39.26169  -94.662711
# 12            5617 Eastern Ave   CANC   39.021462  -94.499507
# 13  6050 NE Pleasant Valley Rd  RESOL   39.218253  -94.509788
# 14          6920 N Overland Dr  RESOL   39.220934  -94.640802
# 15             8442 Wornall Rd  RESOL   38.974578  -94.595409
# 16              8301 Summit St  RESOL   38.978551  -94.597919
# 17                  3300 Paseo  RESOL   39.066564  -94.567348
# 18             1203 W 66th Ter  RESOL   39.008328  -94.603157
# 19           3935 N Antioch Rd  RESOL   39.165508  -94.548483
# 20             1241 W 68th Ter  RESOL   39.005718   -94.60755
# 21         2201 Van Brunt Blvd  RESOL   39.084988  -94.520599
# 22             4710 NW 79th St  RESOL   39.238578  -94.635005

# %%
kc_table_id = "opendatadbt.311.kc311"
dataset_ref = client.dataset('311')
table_ref = dataset_ref.table('kc311')
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_TRUNCATE",
)

client.load_table_from_dataframe(
    kc_df, table_ref, job_config=job_config
).result()  # Make an API request.
